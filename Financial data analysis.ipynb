# %%
import pandas as pd
import numpy as nd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Finance_data.csv")
data
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
data.shape
# Out:
# (40, 24)

# %%
data.ndim
# Out:
# 2

# %%
data.size
# Out:
# 960

# %%
data.info
# Out:
# <bound method DataFrame.info of     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
data.dtypes
# Out:
# gender                               object
# age                                   int64
# Investment_Avenues                   object
# Mutual_Funds                          int64
# Equity_Market                         int64
# Debentures                            int64
# Government_Bonds                      int64
# Fixed_Deposits                        int64
# PPF                                   int64
# Gold                                  int64
# Stock_Marktet                        object
# Factor                               object
# Objective                            object
# Purpose                              object
# Duration                             object
# Invest_Monitor                       object
# Expect                               object
# Avenue                               object
# What are your savings objectives?    object
# Reason_Equity                        object
# Reason_Mutual                        object
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
data.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# gender                               0
# age                                  0
# Investment_Avenues                   0
# Mutual_Funds                         0
# Equity_Market                        0
# Debentures                           0
# Government_Bonds                     0
# Fixed_Deposits                       0
# PPF                                  0
# Gold                                 0
# Stock_Marktet                        0
# Factor                               0
# Objective                            0
# Purpose                              0
# Duration                             0
# Invest_Monitor                       0
# Expect                               0
# Avenue                               0
# What are your savings objectives?    0
# Reason_Equity                        0
# Reason_Mutual                        0
# Reason_Bonds                         0
# Reason_FD                            0
# Source                               0
# dtype: int64

# %%
#Count of people who related to stock market and investment by gender
plt.style.use('ggplot')
data['gender'].value_counts().plot(kind='bar', figsize=(8,5), ylabel='Count of People', xlabel='Gender')
plt.legend()
plt.show()

# %%
data.head(10)
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
# 5  Female   24                 No             7              5           4
# 6  Female   27                Yes             3              6           4
# 7    Male   21                Yes             2              3           7
# 8    Male   35                Yes             2              4           7
# 9    Male   31                Yes             1              3           7
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# ...

# %%
data.tail()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 35   Male   30                Yes             1              4           6
# 36   Male   30                Yes             2              4           7
# 37   Male   25                Yes             5              4           7
# 38   Male   31                Yes             2              4           7
# 39   Male   29                Yes             4              3           5
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ...   Duration  \
# 35                 5               3    2     7  ...  3-5 years
# 36                 5               1    3     6  ...  1-3 years
# 37                 6               1    2     3  ...  3-5 years
# 38                 5               3    1     6  ...  1-3 years
# 39                 7               2    1     6  ...  3-5 years
#
#    Invest_Monitor   Expect                 Avenue  \
# 35        Monthly  20%-30%         Fixed Deposits
# ...

# %%
data.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
data["gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
#remove the unneccesary data's
data.drop("Reason_Equity",axis=1,inplace=True)
data.drop("Reason_Mutual",axis=1,inplace=True)
data.drop("Reason_FD",axis=1,inplace=True)
data.drop("Reason_Bonds",axis=1,inplace=True)

# %%
data
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
data["gender"].value_counts()
# Out:
# Male      25
# Female    15
# Name: gender, dtype: int64

# %%
pd.crosstab(data.Avenue,data.gender,values=data.Debentures,aggfunc=sum)
# Out:
# gender                 Female  Male
# Avenue
# Equity                     12    41
# Fixed Deposits             21    37
# Mutual Fund                38    61
# Public Provident Fund       7    13

# %%
data["Avenue"].value_counts()
# Out:
# Mutual Fund              18
# Equity                   10
# Fixed Deposits            9
# Public Provident Fund     3
# Name: Avenue, dtype: int64

# %%
data.groupby("gender")["age"].mean()
# Out:
# gender
# Female    27.733333
# Male      27.840000
# Name: age, dtype: float64

# %%
data["<=30"]=data["age"].apply(lambda age: "true" if age<=30 else "False")

# %%
data
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
#visulation
fig =data[data.gender=="Female"].plot(kind='line',x='Avenue',y='age',color='blue', label='Female',  figsize= (10,6))
data[data.gender=="Male"].plot(kind='line',x='Avenue',y='age',color='red', label='Male',  ax=fig)
plt.show()

# %%
#Count of people who related to stock market and investment by gender
plt.style.use('ggplot')
data['gender'].value_counts().plot(kind='bar', figsize=(8,5), ylabel='Count of People', xlabel='Gender')
plt.legend()
plt.show()

# %%
data['Factor'].value_counts().plot(kind='bar')
plt.ylabel('counts')
plt.title('Factor of Investment')
plt.show()

# %%
sns.countplot(x=data['Duration'], hue=data['Invest_Monitor'], palette='coolwarm', edgecolor='black')
plt.legend(loc='upper right')
plt.show()

# %%
#Show frequency age range by gender 
data.groupby('gender').age.plot(kind='kde')
plt.xlabel('age')
plt.legend()
plt.show()

# %%
data.iloc[:, 3:10].sum().plot(kind='bar')
plt.title('The sum of types of investments')
plt.ylabel('preference (less like)')
plt.show()

# %%
sns.stripplot(y="Fixed_Deposits",x="gender",data=data)
plt.show()

# %%
#Duration of invest and invest monitor
fig, axes = plt.subplots(1, 2, figsize=(15,5))

sns.countplot(ax=axes[0], x=data['Duration'])
axes[0].set_title('Prefer to keep your money')

sns.countplot(ax=axes[1], x=data['Invest_Monitor'])
axes[1].set_title('Invest Monitor')
# Out:
# Text(0.5, 1.0, 'Invest Monitor')

# %%
sns.stripplot(y="Mutual_Funds",x="gender",data=data)
plt.show()

# %%
sns.stripplot(y="Equity_Market",x="gender",data=data)
plt.show()

# %%
data.hist(bins=25,figsize=(12,6))
plt.show()

# %%
sns.pairplot(data=data,hue="Avenue",height=3)
plt.show()

# %%
data.groupby("gender").agg(["mean","median"])
# Out:
#               age        Mutual_Funds        Equity_Market        Debentures  \
#              mean median         mean median          mean median       mean
# gender
# Female  27.733333   27.0     2.733333    2.0      3.333333    3.0       5.20
# Male    27.840000   27.0     2.440000    2.0      3.560000    4.0       6.08
#
#               Government_Bonds        Fixed_Deposits              PPF         \
#        median             mean median           mean median      mean median
# gender
# Female    5.0         4.333333    5.0            4.2    4.0  2.333333    1.0
# Male      7.0         4.840000    5.0            3.2    3.0  1.840000    1.0
#
#             Gold
#             mean median
# gender
# Female  5.866667    6.0
# Male    6.040000    6.0

# %%
#machine learning model
#linear Regression model
#feature selction
x=data.iloc[:,3:-11]
y=data.iloc[:,-4]

# %%
x
# Out:
#     Mutual_Funds  Equity_Market  Debentures  Government_Bonds  Fixed_Deposits  \
# 0              1              2           5                 3               7
# 1              4              3           2                 1               5
# 2              3              6           4                 2               5
# 3              2              1           3                 7               6
# 4              2              1           3                 6               4
# 5              7              5           4                 6               3
# 6              3              6           4                 2               5
# 7              2              3           7                 4               6
# 8              2              4           7                 5               3
# 9              1              3           7                 4               5
# 10             2              4           7                 5               3
# ...

# %%
y
# Out:
# 0               Mutual Fund
# 1               Mutual Fund
# 2                    Equity
# 3                    Equity
# 4                    Equity
# 5               Mutual Fund
# 6                    Equity
# 7               Mutual Fund
# 8                    Equity
# 9            Fixed Deposits
# 10              Mutual Fund
# 11              Mutual Fund
# 12              Mutual Fund
# 13              Mutual Fund
# 14           Fixed Deposits
# 15              Mutual Fund
# 16           Fixed Deposits
# 17              Mutual Fund
# 18              Mutual Fund
# 19           Fixed Deposits
# 20              Mutual Fund
# 21                   Equity
# 22              Mutual Fund
# 23    Public Provident Fund
# 24    Public Provident Fund
# 25              Mutual Fund
# 26              Mutual Fund
# 27           Fixed Deposits
# 28                   Equity
# 29              Mutual Fund
# 30              Mutual Fund
# 31           Fixed Deposits
# 32                   Equity
# ...

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=8)

# %%
model.predict([[2,5,4,2,2,2,2]])
# Out:
# array(['Equity'], dtype=object)

# %%
ypredict=model.predict(xtest)

# %%
#evaluation of a model
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
print("the accuracy score",accuracy_score(ypredict,ytest))
# Out:
# the accuracy score 0.375

# %%
print(classification_report(ypredict,ytest))
# Out:
#                 precision    recall  f1-score   support
#
#         Equity       0.00      0.00      0.00         1
# Fixed Deposits       0.00      0.00      0.00         1
#    Mutual Fund       0.75      0.50      0.60         6
#
#       accuracy                           0.38         8
#      macro avg       0.25      0.17      0.20         8
#   weighted avg       0.56      0.38      0.45         8

# %%
#support vector
from sklearn.svm import SVC
model=SVC()
model.fit(xtrain,ytrain)
ypredict=model.predict(xtest)

# %%
print(classification_report(ypredict,ytest))
# Out:
#                 precision    recall  f1-score   support
#
#         Equity       0.00      0.00      0.00         2
# Fixed Deposits       0.00      0.00      0.00         0
#    Mutual Fund       0.75      0.50      0.60         6
#
#       accuracy                           0.38         8
#      macro avg       0.25      0.17      0.20         8
#   weighted avg       0.56      0.38      0.45         8
# C:\Users\Subashini\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Subashini\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
#decision tree model
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(xtrain,ytrain)
ypredict=model.predict(xtest)

# %%
print(classification_report(ypredict,ytest))
# Out:
#                 precision    recall  f1-score   support
#
#         Equity       0.00      0.00      0.00         0
# Fixed Deposits       0.33      0.33      0.33         3
#    Mutual Fund       0.50      0.40      0.44         5
#
#       accuracy                           0.38         8
#      macro avg       0.28      0.24      0.26         8
#   weighted avg       0.44      0.38      0.40         8
# C:\Users\Subashini\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Subashini\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(n_neighbors=8)
model.fit(xtrain, ytrain)

ypred = model.predict(xtest)

# %%
print(classification_report(ypredict,ytest))
# Out:
#                 precision    recall  f1-score   support
#
#         Equity       0.00      0.00      0.00         0
# Fixed Deposits       0.33      0.33      0.33         3
#    Mutual Fund       0.50      0.40      0.44         5
#
#       accuracy                           0.38         8
#      macro avg       0.28      0.24      0.26         8
#   weighted avg       0.44      0.38      0.40         8
# C:\Users\Subashini\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Subashini\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1248: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...
